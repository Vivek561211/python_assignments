# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
data=pd.read_csv('/Users/vivekborade/Downloads/data.csv')
df=pd.DataFrame(data)
df.head(10)
# Out:
#    number_courses  time_study   Marks
# 0               3       4.508  19.202
# 1               4       0.096   7.734
# 2               4       3.133  13.811
# 3               6       7.909  53.018
# 4               8       7.811  55.299
# 5               6       3.211  17.822
# 6               3       6.063  29.889
# 7               5       3.413  17.264
# 8               4       4.410  20.348
# 9               3       6.173  30.862

# %%
number_courses = df['number_courses'].tolist()

# %%
Marks=df['Marks'].tolist()

# %%
time_study=df['time_study'].tolist()

# %%
x=Marks
y=time_study
plt.plot(x,y)
plt.title("Marks vs Time Studied line Graph")
plt.show()

# %%
plt.bar(x,y)
plt.title("Marks vs Time Studied Bar Graph")
plt.show()

# %%
plt.scatter(x,y,marker='*')
plt.title("Marks vs Time Studied scatter Graph")
plt.show()

# %%
x=Marks
y=time_study
plt.stem(x,y)
plt.show()

# %%
plt.step(x,y)
plt.show()

# %%
plt.fill_between(x,y)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.hist(x)
plt.show()

# %%
plt.boxplot(x)
plt.show()

# %%
plt.violinplot(x)
plt.show()

# %%
plt.hist2d(x,y)
plt.show()

# %%
plt.pie(x)
plt.show()
